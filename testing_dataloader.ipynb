# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import torchvision.transforms as transforms
from bbox import *
import cv2

## ========= Change to your dataloader =====================
from datagen import DataGenerator

transform = transforms.Compose([
        transforms.ToTensor()
    ])

img_size = 448
img_folder = 'hw2_train_val/train15000/'
train_dataset = DataGenerator(parent_dir=img_folder, img_size=img_size, S=7, B=2, C=16, transform=transform, num = 300)

# %%
img_name, img, target  = train_dataset.__getitem__(87)

boxes_xy, cls_names = target_to_boxes_xy(target)

imshow_with_boxes(img.permute(1,2,0), boxes_xy, cls_names)

# %%
visualize_bbox(img_name, boxes_xy, cls_names, np.zeros(len(boxes_xy)))
print(img_name)
# Out:
# 13963

# %%
visualize_bbox_gt(img_name, img_size = 512)
